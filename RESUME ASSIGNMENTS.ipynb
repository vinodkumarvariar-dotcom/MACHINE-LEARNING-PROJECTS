# %% [markdown]
# VINOD KUMAR K V
#
# Junior Data Scientist
#
# 9744608583
#
# vinodkumarvariar@gmail.com
#
# https://www.linkedin.com/in/vinod-kumar-k-v-kizhakke-veedu-
#
# --------------------------------------------------------------------------------------------------------------------------
# SKILLS  SUMMARY
#
# Programming: Python,  SQL, Java, C#, JavaScript, HTML, CSS . PHP
#
# Data Analysis Tools: Tableau, Power BI, Excel, Google Data Studio,
#
# Big Data & Machine Learning: TensorFlow, Scikit-learn, Hadoop, Spark, AWS Big Data
#
# Database & ETL:  MySQL, EXCEL
#
#
#
# PROFESSIONAL EXPERIENCE
#
# SALES MANAGER
#
# Deepam Enterprises Ltd. (Distributor of Fuel Filters)- June 2016 to December 2025
#
# ● Developed comprehensive Sales strategies and prepared detailed presentations that increased new customer acquisition by 30% in two years.
#
# ● Utilized rigorous analytics processes to identify market trends and opportunities for growth.
#
# ● Monitored customer satisfaction levels, evaluated feedback, and coordinated with Sales development teams for impactful improvements.
#
# ● Managed day-to-day operations of the team, including performance reviews, team meetings, coaching sessions, and other activities
#
# ● Created successful Sales, resulting in an increase of new customers by 35% within a year.
#
# ● Developed customer satisfaction plans that improved client retention
#
# ● Established strong relationships with key partners across the region to identify new opportunities for expansion.
#
# ● Provided technical support during the client onboarding process.
#
# Education
#
#  Bachelor of Commerce – (Calicut University)
#
# Certificate Course in Yogic Science - (Kannur University)
#
# Data Science with Gen AI from ENTRI
#
# PROJECTS
#
# 01.	Regression Modelling
#
# Linear, Random Forest, Gradient Boosting, SVR, data preprocessing, EDA, evaluated models using MAE, MSE, RMSE and R2 metrics.
# Python, Pandas, NumPy, Matplotlib, Scikit-learn, Seaborn
#
# 02.	Classification Modelling
#
# Executed Logistic Regression, Random Forest, SVM, KNN, Decision Tree,
# Data Preprocessing (Preprocessing numerical and categorical features, handled missing values, and performed feature encoding.) evaluated model performance using confusion matrix, accuracy, precision, and recall on imbalanced data.  feature scaling and evaluated models using accuracy, precision, recall, F-1 score, and confusion matrix
# Python, Pandas, NumPy, Matplotlib, Scikit-learn, Seaborn
# Specialization in Machine Learning and Artificial Intelligence
#
#
# Interests
#
# ● Running marathon Data Analysis
#
# ● Traveling to different countries and exploring nature.
