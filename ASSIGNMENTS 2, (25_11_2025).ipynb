# %% [markdown]
# PYTHON MODULE- END PROJECT

# %% [markdown]
# Build a Python-based Student Management System using the concepts of Python programming covered in your syllabus. This system should allow users (admin/teacher) to add, view, update, and delete student records.

# %% [markdown]
# Login System

# %%
def login(username, password):
    if username == "moothedath_high_school_taliparamba" and password == "mhs_tpba":
        return True
    else:
        return False

# %% [markdown]
# check password

# %%
def check_passwod(password):
  if password=="mhs_tpba":
    return True
  else:
    return False

# %% [markdown]
# Add New Student Record

# %%
def add_student_data(Name,Roll_Number, age, Department,Marks):
    student = {"Name": Name, "Roll_Number": Roll_Number, "Age": Age,"Department": Department, "Marks": Marks}
    students_data.append(student)
    print(f"{name} added with details.")

# %% [markdown]
# View Student Record

# %%
students_data = [
    {'Name': 'VINODKUMAR', 'Roll_Number': '1001', 'Age': '25','Department': 'Data_Science','marks': {'Maths & Statistics': 90, 'Science': 85}},
    {'Name': 'MANOJKUMAR', 'Roll_Number': '1002', 'Age': '26','Department': 'Web_Development','marks': {'Maths & Statistics': 82, 'Science': 81}},
    {'Name': 'RAVIKUMAR', 'Roll_Number': '1003', 'Age': '22','Department': 'Full_Stack','marks': {'Maths & Statistics': 80, 'Science': 83}},
    {'Name': 'RAJESHKUMAR', 'Roll_Number': '1004', 'Age': '24','Department': 'Ui-Ux','marks': {'Maths & Statistics': 86, 'Science': 80}},
    ]
print(students_data)
# Out:
# [{'Name': 'VINODKUMAR', 'Roll_Number': '1001', 'Age': '25', 'Department': 'Data_Science', 'marks': {'Maths & Statistics': 90, 'Science': 85}}, {'Name': 'MANOJKUMAR', 'Roll_Number': '1002', 'Age': '26', 'Department': 'Web_Development', 'marks': {'Maths & Statistics': 82, 'Science': 81}}, {'Name': 'RAVIKUMAR', 'Roll_Number': '1003', 'Age': '22', 'Department': 'Full_Stack', 'marks': {'Maths & Statistics': 80, 'Science': 83}}, {'Name': 'RAJESHKUMAR', 'Roll_Number': '1004', 'Age': '24', 'Department': 'Ui-Ux', 'marks': {'Maths & Statistics': 86, 'Science': 80}}]

# %% [markdown]
# Update students_data

# %%
students_data = [
    {'Name': 'VINODKUMAR', 'Roll_Number': '1001', 'Age': '25','Department': 'Data_Science','marks': {'Maths & Statistics': 90, 'Science': 85}},
    {'Name': 'MANOJKUMAR', 'Roll_Number': '1002', 'Age': '26','Department': 'Web_Development','marks': {'Maths & Statistics': 82, 'Science': 81}},
    {'Name': 'RAVIKUMAR', 'Roll_Number': '1003', 'Age': '22','Department': 'Full_Stack','marks': {'Maths & Statistics': 80, 'Science': 83}},
    {'Name': 'RAJESHKUMAR', 'Roll_Number': '1004', 'Age': '24','Department': 'Ui-Ux','marks': {'Maths & Statistics': 86, 'Science': 80}},
    ]
def Ve_students_data(Roll_Number, new_details):
    for student in students_data:
        if student['Roll_Number'] == Roll_Number:
            student.update(new_details)
        break
    Ve_students_data("1001",{"Roll_Number": "2001"})
    print("\nAfter update:")
    print(students_data)

# %% [markdown]
# Delete Student Record

# %%
students_data = [
    {'Name': 'VINODKUMAR', 'Roll_Number': '1001', 'Age': '25','Department': 'Data_Science','marks': {'Maths & Statistics': 90, 'Science': 85}},
    {'Name': 'MANOJKUMAR', 'Roll_Number': '1002', 'Age': '26','Department': 'Web_Development','marks': {'Maths & Statistics': 82, 'Science': 81}},
    {'Name': 'RAVIKUMAR', 'Roll_Number': '1003', 'Age': '22','Department': 'Full_Stack','marks': {'Maths & Statistics': 80, 'Science': 83}},
    {'Name': 'RAJESHKUMAR', 'Roll_Number': '1004', 'Age': '24','Department': 'Ui-Ux','marks': {'Maths & Statistics': 86, 'Science': 80}},
    ]
print(students_data)
def remove_student(Roll):
    for student in students_data:
        if student['Roll_Number'] == Roll:
            students_data.remove(student)
        break
    remove_student("1002")
    print("\nAfter update:")
    print(students_data)
# Out:
# [{'Name': 'VINODKUMAR', 'Roll_Number': '1001', 'Age': '25', 'Department': 'Data_Science', 'marks': {'Maths & Statistics': 90, 'Science': 85}}, {'Name': 'MANOJKUMAR', 'Roll_Number': '1002', 'Age': '26', 'Department': 'Web_Development', 'marks': {'Maths & Statistics': 82, 'Science': 81}}, {'Name': 'RAVIKUMAR', 'Roll_Number': '1003', 'Age': '22', 'Department': 'Full_Stack', 'marks': {'Maths & Statistics': 80, 'Science': 83}}, {'Name': 'RAJESHKUMAR', 'Roll_Number': '1004', 'Age': '24', 'Department': 'Ui-Ux', 'marks': {'Maths & Statistics': 86, 'Science': 80}}]

# %% [markdown]
# Exit Option

# %%
import sys
if complete_students_data:
    sys.exit(0)
else:
    "continue"

# %% [markdown]
#  Use File Handling to store student data persistently

# %%
def add_student():
    roll = input("Enter Roll Number: ")
    name = input("Enter Student Name: ")
    marks = input("Enter Marks: ")

    with open("students.txt", "a") as file:
        file.write(f"{roll},{name},{marks}\n")

    print("Student record added successfully!\n")


def view_students():
    try:
        with open("students.txt", "r") as file:
            print("\n----- Stored Student Records -----")
            for line in file:
                roll, name, marks = line.strip().split(',')
                print(f"Roll: {roll}, Name: {name}, Marks: {marks}")
            print("----------------------------------\n")
    except FileNotFoundError:
        print("No student data found! Please add students first.\n")


# Main Menu
while True:
    print("1. Add Student")
    print("2. View Students")
    print("3. Exit")

    choice = input("Enter choice: ")

    if choice == "1":
        add_student()
    elif choice == "2":
        view_students()
    elif choice == "3":
        print("Exiting Program...")
        break
    else:
        print("Invalid choice! Try again.\n")
# Out:
# 1. Add Student
# 2. View Students
# 3. Exit

# %% [markdown]
# Search student by name or department

# %%
students_data = [
    {'Name': 'VINODKUMAR', 'Roll_Number': '1001', 'Age': '25','Department': 'Data_Science','marks': {'Maths & Statistics': 90, 'Science': 85}},
    {'Name': 'MANOJKUMAR', 'Roll_Number': '1002', 'Age': '26','Department': 'Web_Development','marks': {'Maths & Statistics': 82, 'Science': 81}},
    {'Name': 'RAVIKUMAR', 'Roll_Number': '1003', 'Age': '22','Department': 'Full_Stack','marks': {'Maths & Statistics': 80, 'Science': 83}},
    {'Name': 'RAJESHKUMAR', 'Roll_Number': '1004', 'Age': '24','Department': 'Ui-Ux','marks': {'Maths & Statistics': 86, 'Science': 80}},
    ]

def search_student(students_list, search_term, search_by='name'):
  results = []
  for student in students_data:
    if search_by == 'name':
      return results
    print("Searching by name '':")
found_by_name = search_student(students_data, 'VINODKUMAR', 'name')
for student in found_by_name:
    print(student)

# %% [markdown]
# Auto-generate student ID

# %%
import uuid

unique_id = uuid.uuid4()
print(f"Random UUID: {'Roll_Number'}")
# Out:
# Random UUID: Roll_Number

# %% [markdown]
#  View top-performing students

# %%
students_data =[
    {'Name': 'VINODKUMAR', 'Id.Number': '1001','marks': {'Maths':95, 'Statistics': 90, 'Science': 85,'TOTAL MARK': '270',}},
    {'Name': 'MANOJKUMAR', 'Id.Number': '1002','marks': {'Maths':88, 'Statistics': 82, 'Science': 80,'TOTAL MARK': '250',}},
    {'Name': 'RAVIKUMAR', 'Id.Number': '1003', 'marks': {'Maths':82, 'Statistics': 80, 'Science': 83,'TOTAL MARK': '245',}},
    {'Name': 'RAJESHKUMAR','Id.Number': '1004','marks': {'Maths':80, 'Statistics': 86, 'Science': 80,'TOTAL MARK': '246',}}
    ]
print(students_data)
# Out:
# [{'Name': 'VINODKUMAR', 'Id.Number': '1001', 'marks': {'Maths': 95, 'Statistics': 90, 'Science': 85, 'TOTAL MARK': '270'}}, {'Name': 'MANOJKUMAR', 'Id.Number': '1002', 'marks': {'Maths': 88, 'Statistics': 82, 'Science': 80, 'TOTAL MARK': '250'}}, {'Name': 'RAVIKUMAR', 'Id.Number': '1003', 'marks': {'Maths': 82, 'Statistics': 80, 'Science': 83, 'TOTAL MARK': '245'}}, {'Name': 'RAJESHKUMAR', 'Id.Number': '1004', 'marks': {'Maths': 80, 'Statistics': 86, 'Science': 80, 'TOTAL MARK': '246'}}]

# %% [markdown]
# Use modules like datetime to show time of entry

# %%
import datetime

x = datetime.datetime.now()
print(x)


time_only = entry_time.time()
print("Time part only:", time_only)
# Out:
# 2025-11-22 16:38:19.714695
# Time part only: 16:33:40.329844

# %% [markdown]
# Create a custom module

# %%
class MyClass:
        def __init__(self, name,age):
            self.name= name
            self.age = age
            p1= person("john",20)
            print(p1.name)
            print(p1.age)

# %% [markdown]
# Handle invalid inputs using exception handling

# %%
def get_positive integer_input("Positive_integer_Number: "):
if value<=0:
    print("value error")
else:
    print(get_positive integer_input("Positive_integer_Number: "))
# Out:
#   File "/tmp/ipython-input-730005975.py", line 1
#     def get_positive integer_input("Positive_integer_Number: ")
#                      ^
# SyntaxError: expected '('
